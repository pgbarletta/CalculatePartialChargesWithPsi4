# %% [markdown]
# ## Calculate (RESP) partial charges with Psi4
# import the following modules

# %%
import os
import psi4
import resp
from openbabel import openbabel as ob
from rdkit import Chem
from rdkit.Chem import AllChem

# %% [markdown]
# ### some helper functions

# %%
def neutralize_atoms(mol):
    pattern = Chem.MolFromSmarts("[+1!h0!$([*]~[-1,-2,-3,-4]),-1!$([*]~[+1,+2,+3,+4])]")
    at_matches = mol.GetSubstructMatches(pattern)
    at_matches_list = [y[0] for y in at_matches]
    if len(at_matches_list) > 0:
        for at_idx in at_matches_list:
            atom = mol.GetAtomWithIdx(at_idx)
            chg = atom.GetFormalCharge()
            hcount = atom.GetTotalNumHs()
            atom.SetFormalCharge(0)
            atom.SetNumExplicitHs(hcount - chg)
            atom.UpdatePropertyCache()
    return mol

def cleanUp(psi4out_xyz):
    deleteTheseFiles = ['1_default_grid.dat','1_default_grid_esp.dat','grid.dat','timer.dat']
    deleteTheseFiles.append(psi4out_xyz)
    for fileName in deleteTheseFiles:
        if os.path.exists(fileName):
            os.remove(fileName)

def get_xyz_coords(mol):
    if not mol is None:
        num_atoms = mol.GetNumAtoms()
        xyz_string=""
        for counter in range(num_atoms):
            pos=mol.GetConformer().GetAtomPosition(counter)
            xyz_string = xyz_string + ("%s %12.6f %12.6f %12.6f\n" % (mol.GetAtomWithIdx(counter).GetSymbol(), pos.x, pos.y, pos.z) )
    return xyz_string


def calcRESPCharges(mol, basisSet, method, gridPsi4 = 1):
    options = {'BASIS_ESP': basisSet,
               'METHOD_ESP': method,
               'RESP_A': 0.0005,
               'RESP_B': 0.1,
               'VDW_SCALE_FACTORS':[1.4, 1.6, 1.8, 2.0],
               'VDW_POINT_DENSITY':int(gridPsi4)
    }

    resp_charges = resp.resp([mol], options)
    return resp_charges

# %% [markdown]
# ### Set some variables and stuff

# %%
method = 'b3lyp'
basisSet = '3-21g' #'6-31G**'
neutralize = True
psi4.set_memory('10 GB')
obConversion = ob.OBConversion()
obConversion.SetInAndOutFormats("xyz", "mol2")
singlePoint = True
path = "./data"
# Out:
#   Memory set to   9.313 GiB by Python driver.

# %% [markdown]
# ### Read sdf file (3D) into a list

# %%
inputFile = "./data/txa.sdf"
molList = Chem.SDMolSupplier(inputFile, removeHs=False)

# %% [markdown]
# ### Loop over compounds in list and calculate partial charges

# %%
for mol in molList:
    
    if not mol is None:

        molId = mol.GetProp("_Name")
        print('Trying:', molId)
        
        if neutralize:
            mol = neutralize_atoms(mol)
            mol = Chem.AddHs(mol)

        xyz_string = get_xyz_coords(mol) 
        psi_mol = psi4.geometry(xyz_string)

        ### single point calculation
        outfile_mol2 = inputFile[:-4]+".mol2"

        if singlePoint:
            print('Running singlepoint...')
            resp_charges = calcRESPCharges(psi_mol, basisSet, method, gridPsi4 = 1)

        else:
            print('Running geometry optimization...')            
            methodNbasisSet = method+"/"+basisSet
            psi4.optimize(methodNbasisSet, molecule=psi_mol)
            resp_charges = calcRESPCharges(psi_mol, basisSet, method, gridPsi4 = 1)            

        ### save coords to xyz file 
        psi4out_xyz = molId + '.xyz'
        psi_mol.save_xyz_file(psi4out_xyz,1)

        ### read xyz file and write as mol2 
        ob_mol = ob.OBMol()
        obConversion.ReadFile(ob_mol, psi4out_xyz)

        ### set new partial charges
        count = 0
        for atom in ob.OBMolAtomIter(ob_mol):
            newChg = resp_charges[1][count]
            atom.SetPartialCharge(newChg)
            count += 1

        ### write as mol2 
        outfile_mol2 = path+"/"+molId+"_partialChgs.mol2"
        print("Finished. Saved compound with partial charges as mol2 file: %s" % outfile_mol2)
        obConversion.WriteFile(ob_mol, outfile_mol2)

        ### clean up
        cleanUp(psi4out_xyz)
# Out:
# Trying: TXA
# Running singlepoint...
#
# *** tstart() called on pbarletta-xps
# *** at Fri Jun 17 09:50:10 2022
#
#    => Loading Basis Set <=
#
#     Name: 3-21G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1          entry N          line    79 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 2, 4, 6-11 entry C          line    68 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 3, 5       entry O          line    90 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 12-26      entry H          line    21 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N           -2.936148864264     2.444532495022     1.176693306151    14.003074004430
#          C            0.844851135736    -0.620467504978    -0.164306693849    12.000000000000
#          O            3.135851135736    -1.517467504978    -0.030306693849    15.994914619570
#          C            0.987851135736     0.648532495022    -0.895306693849    12.000000000000
#          O            1.513851135736    -2.816467504978    -0.621306693849    15.994914619570
#          C           -0.321148864264     1.346532495022    -1.085306693849    12.000000000000
#          C           -1.223148864264     1.289532495022     0.074693306151    12.000000000000
#          C           -1.334148864264    -0.045467504978     0.801693306151    12.000000000000
#          C           -0.023148864264    -0.739467504978     1.034693306151    12.000000000000
#          C           -2.693148864264     1.930532495022    -0.128306693849    12.000000000000
#          C            1.936851135736    -1.668467504978    -0.240306693849    12.000000000000
#          H           -0.150148864264     2.382832495022    -1.381506693849     1.007825032230
#          H           -0.834748864264     0.884332495022    -1.929906693849     1.007825032230
#          H            1.647551135736     1.296432495022    -0.316506693849     1.007825032230
#          H            1.483851135736     0.499632495022    -1.856406693849     1.007825032230
#          H           -0.191048864264    -1.779367504978     1.322393306151     1.007825032230
#          H            0.484551135736    -0.266867504978     1.876593306151     1.007825032230
#          H           -1.846248864264     0.067032495022     1.757793306151     1.007825032230
#          H           -1.969248864264    -0.703867504978     0.206693306151     1.007825032230
#          H           -0.683448864264     1.931532495022     0.777393306151     1.007825032230
#          H           -3.437348864264     1.192632495022    -0.434006693849     1.007825032230
#          H           -2.683848864264     2.744332495022    -0.855706693849     1.007825032230
#          H           -3.872648864264     2.839632495022     1.207493306151     1.007825032230
#          H           -2.972648864264     1.670832495022     1.832893306151     1.007825032230
#          H            0.168951135736    -1.083067504978    -0.889506693849     1.007825032230
#          H            3.590451135736    -2.354167504978    -0.152206693849     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.09554  B =      0.01729  C =      0.01609 [cm^-1]
#   Rotational constants: A =   2864.26911  B =    518.23149  C =    482.22438 [MHz]
#   Nuclear repulsion =  656.868063455208016
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 86
#   Nalpha       = 43
#   Nbeta        = 43
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 3-21G
#     Blend: 3-21G
#     Number of shells: 85
#     Number of basis functions: 129
#     Number of Cartesian functions: 129
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         536169
#     Total Blocks           =           3915
#     Max Points             =            256
#     Max Functions          =            107
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (3-21G AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1          entry N          line   258 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 2, 4, 6-11 entry C          line   198 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 3, 5       entry O          line   318 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 12-26      entry H          line    18 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.158 GiB; user supplied 5.705 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5841
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):      12.9079
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (3-21G AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 365
#     Number of basis functions: 1291
#     Number of Cartesian functions: 1291
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#   Cached 100.0% of DFT collocation blocks in 1.280 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 7.0398548750E-03.
#   Reciprocal condition number of the overlap matrix is 1.3069857477E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        129     129
#    -------------------------
#     Total     129     129
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -515.86183431834718   -5.15862e+02   0.00000e+00
#    @DF-RKS iter   1:  -515.53985021167830    3.21984e-01   9.05205e-03 ADIIS/DIIS
#    @DF-RKS iter   2:  -514.99427521356517    5.45575e-01   1.23875e-02 ADIIS/DIIS
#    @DF-RKS iter   3:  -516.07453954725952   -1.08026e+00   3.62144e-03 ADIIS/DIIS
#    @DF-RKS iter   4:  -516.15766994613261   -8.31304e-02   9.21033e-04 ADIIS/DIIS
#    @DF-RKS iter   5:  -516.16268887910451   -5.01893e-03   1.96068e-04 ADIIS/DIIS
#    @DF-RKS iter   6:  -516.16298320317867   -2.94324e-04   5.03569e-05 DIIS
#    @DF-RKS iter   7:  -516.16300177406060   -1.85709e-05   1.46456e-05 DIIS
#    @DF-RKS iter   8:  -516.16300319203845   -1.41798e-06   2.33546e-06 DIIS
#    @DF-RKS iter   9:  -516.16300322524467   -3.32062e-08   9.68946e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   86.0000656009 ; deviation = 6.560e-05
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.102019     2A    -18.986099     3A    -14.212922
#        4A    -10.246220     5A    -10.139538     6A    -10.123442
#        7A    -10.116446     8A    -10.113918     9A    -10.113624
#       10A    -10.113016    11A    -10.106739    12A     -1.168763
#       13A     -0.979262    14A     -0.898709    15A     -0.857194
#       16A     -0.772765    17A     -0.763389    18A     -0.685368
#       19A     -0.648064    20A     -0.629234    21A     -0.601469
#       22A     -0.556276    23A     -0.519001    24A     -0.485712
#       25A     -0.475251    26A     -0.464768    27A     -0.456395
#       28A     -0.445063    29A     -0.441507    30A     -0.425611
#       31A     -0.417903    32A     -0.399281    33A     -0.387670
#       34A     -0.378635    35A     -0.342070    36A     -0.341061
#       37A     -0.321231    38A     -0.314467    39A     -0.300141
#       40A     -0.290495    41A     -0.271705    42A     -0.229875
#       43A     -0.208194
#
#     Virtual:
#
#       44A      0.026947    45A      0.082763    46A      0.103416
#       47A      0.110354    48A      0.133367    49A      0.139040
#       50A      0.156479    51A      0.170091    52A      0.171950
#       53A      0.181931    54A      0.192162    55A      0.197786
#       56A      0.205523    57A      0.212150    58A      0.216830
#       59A      0.233847    60A      0.241189    61A      0.255268
#       62A      0.279196    63A      0.292541    64A      0.308139
#       65A      0.318404    66A      0.334483    67A      0.338651
#       68A      0.380889    69A      0.398960    70A      0.481618
#       71A      0.663898    72A      0.668496    73A      0.685414
#       74A      0.726173    75A      0.728405    76A      0.732733
#       77A      0.743169    78A      0.772035    79A      0.794971
#       80A      0.798541    81A      0.804207    82A      0.818008
#       83A      0.856353    84A      0.870480    85A      0.877389
#       86A      0.913643    87A      0.924167    88A      0.934363
#       89A      0.957964    90A      0.968853    91A      0.980606
#       92A      1.003306    93A      1.010573    94A      1.033600
#       95A      1.049318    96A      1.060203    97A      1.069645
#       98A      1.072697    99A      1.095138   100A      1.110407
#      101A      1.128743   102A      1.139190   103A      1.153196
#      104A      1.168343   105A      1.184561   106A      1.196717
#      107A      1.306388   108A      1.354268   109A      1.384733
#      110A      1.401741   111A      1.450215   112A      1.460169
#      113A      1.478909   114A      1.550103   115A      1.611041
#      116A      1.636025   117A      1.637865   118A      1.707375
#      119A      1.751540   120A      1.839116   121A      1.947353
#      122A      2.011880   123A      2.054951   124A      2.441174
#      125A      2.451395   126A      2.530770   127A      2.675036
#      128A      3.193312   129A      3.311796
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    43 ]
#
#   @DF-RKS Final Energy:  -516.16300322524467
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            656.8680634552080164
#     One-Electron Energy =               -2003.8090907901680566
#     Two-Electron Energy =                 890.0196358831233283
#     DFT Exchange-Correlation Energy =     -59.2416117734080601
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -516.1630032252446654
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the B3LYP density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         10.3686590          -10.5306922           -0.1620332
#  Dipole Y            :         -8.5309128            8.7110603            0.1801474
#  Dipole Z            :         -0.9580994            1.0860716            0.1279722
#  Magnitude           :                                                    0.2740159
#
#  ------------------------------------------------------------------------------------
#
#  Electrostatic potential computed on the grid and written to grid_esp.dat
#
# *** tstop() called on pbarletta-xps at Fri Jun 17 09:50:33 2022
# Module time:
# 	user time   =      22.53 seconds =       0.38 minutes
# 	system time =       0.41 seconds =       0.01 minutes
# 	total time  =         23 seconds =       0.38 minutes
# Total time:
# 	user time   =      88.28 seconds =       1.47 minutes
# 	system time =       2.36 seconds =       0.04 minutes
# 	total time  =        613 seconds =      10.22 minutes
# Finished. Saved compound with partial charges as mol2 file: ./data/TXA_partialChgs.mol2
# Trying: 4piol
# Running singlepoint...
#
# *** tstart() called on pbarletta-xps
# *** at Fri Jun 17 09:50:33 2022
#
#    => Loading Basis Set <=
#
#     Name: 3-21G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8       entry C          line    68 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 9, 23     entry N          line    79 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 10-11     entry O          line    90 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 12-22, 24 entry H          line    21 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C            1.720656539051    -0.224534397337     0.029583403905    12.000000000000
#          C            0.412356539051    -0.559834397337    -0.199216596095    12.000000000000
#          C            2.434456539051    -1.362534397337    -0.384016596095    12.000000000000
#          C           -1.010743460949     1.439165602663    -0.848316596095    12.000000000000
#          C           -1.174643460949     0.489665602663     1.480683403905    12.000000000000
#          C           -2.329443460949     2.168065602663    -0.588916596095    12.000000000000
#          C           -2.486543460949     1.257065602663     1.646283403905    12.000000000000
#          C           -0.909543460949     0.163065602663     0.002383403905    12.000000000000
#          N            1.630456539051    -2.329634397337    -0.834916596095    14.003074004430
#          O            0.345556539051    -1.813734397337    -0.715116596095    15.994914619570
#          O            3.757356539051    -1.571634397337    -0.376116596095    15.994914619570
#          H            2.100556539051     0.701865602663     0.433983403905     1.007825032230
#          H           -0.933243460949     1.189565602663    -1.913816596095     1.007825032230
#          H           -0.171343460949     2.112165602663    -0.624316596095     1.007825032230
#          H           -0.348443460949     1.086065602663     1.891683403905     1.007825032230
#          H           -1.214343460949    -0.434934397337     2.069983403905     1.007825032230
#          H           -2.346143460949     3.104365602663    -1.157316596095     1.007825032230
#          H           -3.174243460949     1.568165602663    -0.947816596095     1.007825032230
#          H           -3.338243460949     0.618765602663     1.380983403905     1.007825032230
#          H           -2.616943460949     1.533065602663     2.698483403905     1.007825032230
#          H           -1.705443460949    -0.539634397337    -0.340116596095     1.007825032230
#          H            3.981756539051    -2.458834397337    -0.721916596095     1.007825032230
#          N           -2.504943460949     2.485465602663     0.836883403905    14.003074004430
#          H           -3.389843460949     2.954965602663     0.965983403905     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.08966  B =      0.01448  C =      0.01437 [cm^-1]
#   Rotational constants: A =   2687.99012  B =    434.03951  C =    430.86437 [MHz]
#   Nuclear repulsion =  709.726345248525377
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 90
#   Nalpha       = 45
#   Nbeta        = 45
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 3-21G
#     Blend: 3-21G
#     Number of shells: 84
#     Number of basis functions: 132
#     Number of Cartesian functions: 132
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         495358
#     Total Blocks           =           3617
#     Max Points             =            256
#     Max Functions          =            109
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (3-21G AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-8       entry C          line   198 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 9, 23     entry N          line   258 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 10-11     entry O          line   318 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 12-22, 24 entry H          line    18 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.165 GiB; user supplied 5.848 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5988
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):      14.9679
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (3-21G AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 372
#     Number of basis functions: 1324
#     Number of Cartesian functions: 1324
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#   Cached 100.0% of DFT collocation blocks in 1.137 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 4.0966300725E-03.
#   Reciprocal condition number of the overlap matrix is 8.1533633242E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        132     132
#    -------------------------
#     Total     132     132
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -568.24629721362874   -5.68246e+02   0.00000e+00
#    @DF-RKS iter   1:  -568.36623556452207   -1.19938e-01   7.31472e-03 ADIIS/DIIS
#    @DF-RKS iter   2:  -568.17175288290071    1.94483e-01   8.69056e-03 ADIIS/DIIS
#    @DF-RKS iter   3:  -568.78279940761718   -6.11047e-01   1.83140e-03 ADIIS/DIIS
#    @DF-RKS iter   4:  -568.80374441057222   -2.09450e-02   7.78185e-04 ADIIS/DIIS
#    @DF-RKS iter   5:  -568.80816945112440   -4.42504e-03   1.84984e-04 ADIIS/DIIS
#    @DF-RKS iter   6:  -568.80841593194828   -2.46481e-04   6.98945e-05 DIIS
#    @DF-RKS iter   7:  -568.80845351171945   -3.75798e-05   2.14769e-05 DIIS
#    @DF-RKS iter   8:  -568.80845669628548   -3.18457e-06   7.62065e-06 DIIS
#    @DF-RKS iter   9:  -568.80845710128858   -4.05003e-07   8.54569e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   89.9998228669 ; deviation = -1.771e-04
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.128877     2A    -19.079325     3A    -14.280591
#        4A    -14.229807     5A    -10.219603     6A    -10.200614
#        7A    -10.149647     8A    -10.146692     9A    -10.146039
#       10A    -10.134577    11A    -10.126789    12A    -10.126272
#       13A     -1.162492    14A     -1.084587    15A     -0.917166
#       16A     -0.863975    17A     -0.826988    18A     -0.782253
#       19A     -0.760919    20A     -0.668307    21A     -0.632207
#       22A     -0.628347    23A     -0.610158    24A     -0.558454
#       25A     -0.535452    26A     -0.511794    27A     -0.489863
#       28A     -0.476433    29A     -0.456028    30A     -0.455566
#       31A     -0.429324    32A     -0.423709    33A     -0.418340
#       34A     -0.398337    35A     -0.392698    36A     -0.384637
#       37A     -0.362536    38A     -0.356022    39A     -0.339969
#       40A     -0.327629    41A     -0.327559    42A     -0.287649
#       43A     -0.261804    44A     -0.240094    45A     -0.207696
#
#     Virtual:
#
#       46A      0.001021    47A      0.070958    48A      0.086188
#       49A      0.094308    50A      0.119819    51A      0.132356
#       52A      0.143841    53A      0.153425    54A      0.157218
#       55A      0.176471    56A      0.177552    57A      0.187399
#       58A      0.191528    59A      0.193373    60A      0.208169
#       61A      0.213349    62A      0.232742    63A      0.256982
#       64A      0.265642    65A      0.274736    66A      0.289176
#       67A      0.294630    68A      0.298397    69A      0.325619
#       70A      0.368543    71A      0.471040    72A      0.508042
#       73A      0.642702    74A      0.677935    75A      0.691739
#       76A      0.701670    77A      0.723318    78A      0.728699
#       79A      0.741867    80A      0.756993    81A      0.759191
#       82A      0.761254    83A      0.789409    84A      0.791722
#       85A      0.818995    86A      0.830571    87A      0.849549
#       88A      0.887631    89A      0.892376    90A      0.928235
#       91A      0.941704    92A      0.960517    93A      0.981169
#       94A      1.004995    95A      1.015090    96A      1.027802
#       97A      1.036830    98A      1.050316    99A      1.067384
#      100A      1.086227   101A      1.099824   102A      1.116134
#      103A      1.121478   104A      1.136338   105A      1.147219
#      106A      1.177226   107A      1.188068   108A      1.219057
#      109A      1.289930   110A      1.296371   111A      1.309804
#      112A      1.387303   113A      1.468588   114A      1.486559
#      115A      1.526295   116A      1.536953   117A      1.604986
#      118A      1.620413   119A      1.662121   120A      1.707578
#      121A      1.783160   122A      1.848091   123A      1.905727
#      124A      1.934264   125A      1.994339   126A      2.007552
#      127A      2.432187   128A      2.478393   129A      2.684134
#      130A      2.742200   131A      3.259102   132A      3.366015
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    45 ]
#
#   @DF-RKS Final Energy:  -568.80845710128858
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            709.7263452485253765
#     One-Electron Energy =               -2180.2126254249960766
#     Two-Electron Energy =                 965.3734891446666779
#     DFT Exchange-Correlation Energy =     -63.6956660694846022
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -568.8084571012885817
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the B3LYP density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         11.7896763          -12.3110205           -0.5213442
#  Dipole Y            :        -10.1669400           10.7037947            0.5368547
#  Dipole Z            :         -3.3147710            3.4969502            0.1821792
#  Magnitude           :                                                    0.7701961
#
#  ------------------------------------------------------------------------------------
#
#  Electrostatic potential computed on the grid and written to grid_esp.dat
#
# *** tstop() called on pbarletta-xps at Fri Jun 17 09:50:54 2022
# Module time:
# 	user time   =      20.65 seconds =       0.34 minutes
# 	system time =       0.27 seconds =       0.00 minutes
# 	total time  =         21 seconds =       0.35 minutes
# Total time:
# 	user time   =     109.44 seconds =       1.82 minutes
# 	system time =       2.63 seconds =       0.04 minutes
# 	total time  =        634 seconds =      10.57 minutes
# Finished. Saved compound with partial charges as mol2 file: ./data/4piol_partialChgs.mol2

# %% [markdown]
# ### acá hago lo mismo, pero con 1 sóla molécula y en 2 stages, como debe ser (supuestamente)

# %%
mol = next(molList)
molId = mol.GetProp("_Name")
print('Trying:', molId)

if neutralize:
    mol = neutralize_atoms(mol)
    mol = Chem.AddHs(mol)

xyz_string = get_xyz_coords(mol) 
psi_mol = psi4.geometry(xyz_string)

### single point calculation
outfile_mol2 = inputFile[:-4]+".mol2"

if singlePoint:
    print('Running singlepoint...')
    resp_charges = calcRESPCharges(psi_mol, basisSet, method, gridPsi4 = 1)

else:
    print('Running geometry optimization...')            
    methodNbasisSet = method+"/"+basisSet
    psi4.optimize(methodNbasisSet, molecule=psi_mol)
    resp_charges = calcRESPCharges(psi_mol, basisSet, method, gridPsi4 = 1)
# Out:
# Trying: TXA
# Running singlepoint...
#
# *** tstart() called on pbarletta-xps
# *** at Fri Jun 17 11:18:10 2022
#
#    => Loading Basis Set <=
#
#     Name: 3-21G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1          entry N          line    79 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 2, 4, 6-11 entry C          line    68 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 3, 5       entry O          line    90 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#     atoms 12-26      entry H          line    21 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/3-21g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N           -2.936148864264     2.444532495022     1.176693306151    14.003074004430
#          C            0.844851135736    -0.620467504978    -0.164306693849    12.000000000000
#          O            3.135851135736    -1.517467504978    -0.030306693849    15.994914619570
#          C            0.987851135736     0.648532495022    -0.895306693849    12.000000000000
#          O            1.513851135736    -2.816467504978    -0.621306693849    15.994914619570
#          C           -0.321148864264     1.346532495022    -1.085306693849    12.000000000000
#          C           -1.223148864264     1.289532495022     0.074693306151    12.000000000000
#          C           -1.334148864264    -0.045467504978     0.801693306151    12.000000000000
#          C           -0.023148864264    -0.739467504978     1.034693306151    12.000000000000
#          C           -2.693148864264     1.930532495022    -0.128306693849    12.000000000000
#          C            1.936851135736    -1.668467504978    -0.240306693849    12.000000000000
#          H           -0.150148864264     2.382832495022    -1.381506693849     1.007825032230
#          H           -0.834748864264     0.884332495022    -1.929906693849     1.007825032230
#          H            1.647551135736     1.296432495022    -0.316506693849     1.007825032230
#          H            1.483851135736     0.499632495022    -1.856406693849     1.007825032230
#          H           -0.191048864264    -1.779367504978     1.322393306151     1.007825032230
#          H            0.484551135736    -0.266867504978     1.876593306151     1.007825032230
#          H           -1.846248864264     0.067032495022     1.757793306151     1.007825032230
#          H           -1.969248864264    -0.703867504978     0.206693306151     1.007825032230
#          H           -0.683448864264     1.931532495022     0.777393306151     1.007825032230
#          H           -3.437348864264     1.192632495022    -0.434006693849     1.007825032230
#          H           -2.683848864264     2.744332495022    -0.855706693849     1.007825032230
#          H           -3.872648864264     2.839632495022     1.207493306151     1.007825032230
#          H           -2.972648864264     1.670832495022     1.832893306151     1.007825032230
#          H            0.168951135736    -1.083067504978    -0.889506693849     1.007825032230
#          H            3.590451135736    -2.354167504978    -0.152206693849     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.09554  B =      0.01729  C =      0.01609 [cm^-1]
#   Rotational constants: A =   2864.26911  B =    518.23149  C =    482.22438 [MHz]
#   Nuclear repulsion =  656.868063455208016
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 86
#   Nalpha       = 43
#   Nbeta        = 43
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 3-21G
#     Blend: 3-21G
#     Number of shells: 85
#     Number of basis functions: 129
#     Number of Cartesian functions: 129
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 5.1.5
#     S. Lehtola, C. Steigemann, M. J. Oliveira, and M. A. Marques, SoftwareX 7, 1 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994) (10.1021/j100096a001)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_B3LYP:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         536169
#     Total Blocks           =           3915
#     Max Points             =            256
#     Max Functions          =            107
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (3-21G AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1          entry N          line   258 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 2, 4, 6-11 entry C          line   198 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 3, 5       entry O          line   318 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 12-26      entry H          line    18 file /home/pbarletta/anaconda3/envs/chemi/share/psi4/basis/def2-universal-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.158 GiB; user supplied 5.705 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5841
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):      12.9079
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (3-21G AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 365
#     Number of basis functions: 1291
#     Number of Cartesian functions: 1291
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#   Cached 100.0% of DFT collocation blocks in 1.280 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 7.0398548750E-03.
#   Reciprocal condition number of the overlap matrix is 1.3069857477E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        129     129
#    -------------------------
#     Total     129     129
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -515.86183431962922   -5.15862e+02   0.00000e+00
#    @DF-RKS iter   1:  -515.53985021299547    3.21984e-01   9.05205e-03 DIIS/ADIIS
#    @DF-RKS iter   2:  -514.99427521492339    5.45575e-01   1.23875e-02 DIIS/ADIIS
#    @DF-RKS iter   3:  -516.07453954858215   -1.08026e+00   3.62144e-03 DIIS/ADIIS
#    @DF-RKS iter   4:  -516.15766994745354   -8.31304e-02   9.21033e-04 DIIS/ADIIS
#    @DF-RKS iter   5:  -516.16268888042430   -5.01893e-03   1.96068e-04 DIIS/ADIIS
#    @DF-RKS iter   6:  -516.16298320449857   -2.94324e-04   5.03569e-05 DIIS
#    @DF-RKS iter   7:  -516.16300177538074   -1.85709e-05   1.46456e-05 DIIS
#    @DF-RKS iter   8:  -516.16300319335994   -1.41798e-06   2.33546e-06 DIIS
#    @DF-RKS iter   9:  -516.16300322656468   -3.32047e-08   9.68946e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   86.0000656009 ; deviation = 6.560e-05
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.102019     2A    -18.986099     3A    -14.212922
#        4A    -10.246220     5A    -10.139538     6A    -10.123442
#        7A    -10.116446     8A    -10.113918     9A    -10.113624
#       10A    -10.113016    11A    -10.106739    12A     -1.168763
#       13A     -0.979262    14A     -0.898709    15A     -0.857194
#       16A     -0.772765    17A     -0.763389    18A     -0.685368
#       19A     -0.648064    20A     -0.629234    21A     -0.601469
#       22A     -0.556276    23A     -0.519001    24A     -0.485712
#       25A     -0.475251    26A     -0.464768    27A     -0.456395
#       28A     -0.445063    29A     -0.441507    30A     -0.425611
#       31A     -0.417903    32A     -0.399281    33A     -0.387670
#       34A     -0.378635    35A     -0.342070    36A     -0.341061
#       37A     -0.321231    38A     -0.314467    39A     -0.300141
#       40A     -0.290495    41A     -0.271705    42A     -0.229875
#       43A     -0.208194
#
#     Virtual:
#
#       44A      0.026947    45A      0.082763    46A      0.103416
#       47A      0.110354    48A      0.133367    49A      0.139040
#       50A      0.156479    51A      0.170091    52A      0.171950
#       53A      0.181931    54A      0.192162    55A      0.197786
#       56A      0.205523    57A      0.212150    58A      0.216830
#       59A      0.233847    60A      0.241189    61A      0.255268
#       62A      0.279196    63A      0.292541    64A      0.308139
#       65A      0.318404    66A      0.334483    67A      0.338651
#       68A      0.380889    69A      0.398960    70A      0.481618
#       71A      0.663898    72A      0.668496    73A      0.685414
#       74A      0.726173    75A      0.728405    76A      0.732733
#       77A      0.743169    78A      0.772035    79A      0.794971
#       80A      0.798541    81A      0.804207    82A      0.818008
#       83A      0.856353    84A      0.870480    85A      0.877389
#       86A      0.913643    87A      0.924167    88A      0.934363
#       89A      0.957964    90A      0.968853    91A      0.980606
#       92A      1.003306    93A      1.010573    94A      1.033600
#       95A      1.049318    96A      1.060203    97A      1.069645
#       98A      1.072697    99A      1.095138   100A      1.110407
#      101A      1.128743   102A      1.139190   103A      1.153196
#      104A      1.168343   105A      1.184561   106A      1.196717
#      107A      1.306388   108A      1.354268   109A      1.384733
#      110A      1.401741   111A      1.450215   112A      1.460169
#      113A      1.478909   114A      1.550103   115A      1.611041
#      116A      1.636025   117A      1.637865   118A      1.707375
#      119A      1.751540   120A      1.839116   121A      1.947353
#      122A      2.011880   123A      2.054951   124A      2.441174
#      125A      2.451395   126A      2.530770   127A      2.675036
#      128A      3.193312   129A      3.311796
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    43 ]
#
#   @DF-RKS Final Energy:  -516.16300322656468
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            656.8680634552080164
#     One-Electron Energy =               -2003.8090907906191660
#     Two-Electron Energy =                 890.0196358822767024
#     DFT Exchange-Correlation Energy =     -59.2416117734303569
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -516.1630032265646832
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the B3LYP density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         10.3686590          -10.5306922           -0.1620332
#  Dipole Y            :         -8.5309128            8.7110603            0.1801474
#  Dipole Z            :         -0.9580993            1.0860716            0.1279722
#  Magnitude           :                                                    0.2740159
#
#  ------------------------------------------------------------------------------------
#
#  Electrostatic potential computed on the grid and written to grid_esp.dat
#
# *** tstop() called on pbarletta-xps at Fri Jun 17 11:18:34 2022
# Module time:
# 	user time   =      23.16 seconds =       0.39 minutes
# 	system time =       0.88 seconds =       0.01 minutes
# 	total time  =         24 seconds =       0.40 minutes
# Total time:
# 	user time   =      23.16 seconds =       0.39 minutes
# 	system time =       0.88 seconds =       0.01 minutes
# 	total time  =         24 seconds =       0.40 minutes

# %%
resp_charges[1]
# Out:
# array([-9.62851554e-01, -1.58568061e-03, -6.28763594e-01, -8.22742078e-03,
#        -5.79626215e-01, -4.36352729e-02, -7.54726919e-03, -5.61995673e-04,
#        -1.15541181e-01,  8.22519833e-02,  6.84958554e-01,  3.74749955e-02,
#        -1.73823171e-02, -1.06635531e-02,  3.11417679e-02,  5.46788466e-02,
#         2.16484769e-02,  2.47363249e-02,  1.92161441e-02,  6.07121101e-02,
#         2.35405911e-02,  8.37639436e-02,  3.78162293e-01,  3.60945445e-01,
#         2.91756998e-02,  4.83978878e-01])

# %% [markdown]
# #### 2nd stage
#
# ##### no intentar correr esto. No lo completé

# %%
options = {'BASIS_ESP': basisSet,
            'METHOD_ESP': method,
            'RESP_A': 0.001,
            'RESP_B': 0.1,
            'VDW_SCALE_FACTORS':[1.4, 1.6, 1.8, 2.0],
            'VDW_POINT_DENSITY':1.0
}

# %% [markdown]
# acá hay q decidir q átomos van a estar constrained.
#
# La 1er constraint global es la carga neta de la molécula (será q `neutralize_atoms()` logra esto neutralizando c/ átomo?).
#
# Luego, c/ átomo equivalente debe tener la constraint de tener la misma carga. Habría q ver como se automatiza esto (detectar automáticamente átomos equivalentes). resp entiende éstas constraints con la opción:
# ```
# options["constraint_group"] = [[7, 9], [8, 10], [1, 4], [2, 3, 5, 6]]
# ```
# [Ejemplo](https://github.com/cdsgroup/resp/blob/master/examples/example4.py)
# `

# %%
# Éste es otro tipo de constraint. Supongo q fija la carga de
# los átomos 5-8 (4-7), p/ q la 2nd stage sólo fitee al resto.

constraint_charge = []
for i in range(4, 8):
    constraint_charge.append([resp_charges[1][i], [i+1]])
options['constraint_charge'] = constraint_charge

# %%
constraint_charge
# Out:
# [[-0.5796262151145127, [5]],
#  [-0.04363527292970923, [6]],
#  [-0.007547269192765417, [7]],
#  [-0.0005619956728749703, [8]]]

# %%
resp_charges2 = resp.resp([mol], options)

# %%
### save coords to xyz file 
psi4out_xyz = molId + '.xyz'
psi_mol.save_xyz_file(psi4out_xyz,1)

### read xyz file and write as mol2 
ob_mol = ob.OBMol()
obConversion.ReadFile(ob_mol, psi4out_xyz)
# Out:
# True

# %% [markdown]
# ##### guarda q openbabel tarda en actualizar las cargas y se terminan guardando las cargas viejas, q no tienen sentido alguno

# %%
print([atom.GetPartialCharge() for atom in ob.OBMolAtomIter(ob_mol)])
# Out:
# [-0.9628515540947828, -0.0015856806069533456, -0.628763594351746, -0.008227420780451418, -0.5796262151145127, -0.04363527292970923, -0.007547269192765417, -0.0005619956728749703, -0.11554118096864227, 0.08225198332500387, 0.6849585540125035, 0.0374749954867026, -0.017382317091470242, -0.010663553131782934, 0.031141767879884607, 0.05467884659913111, 0.021648476935749034, 0.024736324916901965, 0.01921614406649013, 0.06071211014924121, 0.023540591107370383, 0.08376394360248336, 0.37816229319452127, 0.36094544500630515, 0.029175699800740546, 0.48397887785266197]

# %%
### set new partial charges
for i, atom in enumerate(ob.OBMolAtomIter(ob_mol)):
    atom.SetPartialCharge(resp_charges[1][i])

### write as mol2 
outfile_mol2 = path+"/"+molId+"_partialChgs.mol2"
print("Finished. Saved compound with partial charges as mol2 file: %s" % outfile_mol2)
obConversion.WriteFile(ob_mol, outfile_mol2)

### clean up
cleanUp(psi4out_xyz)
# Out:
# Finished. Saved compound with partial charges as mol2 file: ./data/TXA_partialChgs.mol2

# %% [markdown]
# ##### actualizó cargas?

# %%
print([atom.GetPartialCharge() for atom in ob.OBMolAtomIter(ob_mol)])
# Out:
# [-0.9628515540947828, -0.0015856806069533456, -0.628763594351746, -0.008227420780451418, -0.5796262151145127, -0.04363527292970923, -0.007547269192765417, -0.0005619956728749703, -0.11554118096864227, 0.08225198332500387, 0.6849585540125035, 0.0374749954867026, -0.017382317091470242, -0.010663553131782934, 0.031141767879884607, 0.05467884659913111, 0.021648476935749034, 0.024736324916901965, 0.01921614406649013, 0.06071211014924121, 0.023540591107370383, 0.08376394360248336, 0.37816229319452127, 0.36094544500630515, 0.029175699800740546, 0.48397887785266197]
